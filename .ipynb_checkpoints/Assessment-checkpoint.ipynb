# %% [markdown]
# ### Installation et import

# %%
# !pip install ipython-sql
# !pip install sqlalchemy
# !pip install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\marwa\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\marwa\anaconda3\lib\site-packages (from ipython-sql) (3.16.0)
# Requirement already satisfied: ipython in c:\users\marwa\anaconda3\lib\site-packages (from ipython-sql) (8.27.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\marwa\anaconda3\lib\site-packages (from ipython-sql) (2.0.34)
# Requirement already satisfied: sqlparse in c:\users\marwa\anaconda3\lib\site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in c:\users\marwa\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\marwa\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\marwa\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\marwa\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: decorator in c:\users\marwa\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\marwa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\marwa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\marwa\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\marwa\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\marwa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\marwa\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\marwa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\marwa\anaconda3\lib\site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\marwa\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing in c:\users\marwa\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\marwa\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\marwa\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: sqlalchemy in c:\users\marwa\anaconda3\lib\site-packages (2.0.34)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\marwa\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\marwa\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: psycopg2 in c:\users\marwa\anaconda3\lib\site-packages (2.9.10)

# %%
# for data management
import pandas as pd
import numpy as np
import csv
import json
# for queries
import psycopg2
from sqlalchemy import create_engine, text
# for modeling
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Open file

# %%
# opening the raw dataset
df = pd.read_csv('clean-dataset.csv', encoding='utf-8')
df.columns
# Out:
# Index(['     1\tsong_id', 'title', 'artist', 'release_date', 'image_url',
#        'timeSeries', 'summaries'],
#       dtype='object')

# %% [markdown]
# ### Cleaning

# %%
# renaming a column and modifying its data because of an index
df.rename(columns={'     1\tsong_id':'song_id'}, inplace=True)
df['song_id'] = df['song_id'].str.split('\t').str[1]
# Out:
# Index(['song_id', 'title', 'artist', 'release_date', 'image_url', 'timeSeries',
#        'summaries'],
#       dtype='object')

# %% [markdown]
# ### Analysis and observation

# %%
# calculating the size of the largest data in each column
for col in df.columns:
    max_length = df[col].astype(str).str.len().max()
    print(f"Colonne '{col}': longueur max = {max_length}")
# Out:
# Colonne 'song_id': longueur max = 36
# Colonne 'title': longueur max = 208
# Colonne 'artist': longueur max = 564
# Colonne 'release_date': longueur max = 25
# Colonne 'image_url': longueur max = 82
# Colonne 'timeSeries': longueur max = 93171
# Colonne 'summaries': longueur max = 1752

# %%
# discovery of timeSeries structure
json.loads(df['timeSeries'][0])
# Out:
# [{'date': '2024-04-29T00:00:00+00:00',
#   'spotify-streams': 2398,
#   'spotify-popularity': 8},
#  {'date': '2024-04-30T00:00:00+00:00',
#   'spotify-streams': 2404,
#   'spotify-popularity': 8},
#  {'date': '2024-05-01T00:00:00+00:00',
#   'spotify-streams': 2414,
#   'spotify-popularity': 8},
#  {'date': '2024-05-02T00:00:00+00:00',
#   'spotify-streams': 2417,
#   'spotify-popularity': 8},
#  {'date': '2024-05-03T00:00:00+00:00',
#   'spotify-streams': 2428,
#   'spotify-popularity': 8},
#  {'date': '2024-05-04T00:00:00+00:00',
#   'spotify-streams': 2434,
#   'spotify-popularity': 8},
#  {'date': '2024-05-05T00:00:00+00:00',
#   'spotify-streams': 2446,
#   'spotify-popularity': 8},
#  {'date': '2024-05-06T00:00:00+00:00',
#   'spotify-streams': 2456,
#   'spotify-popularity': 8},
#  {'date': '2024-05-07T00:00:00+00:00',
#   'spotify-streams': 2458,
#   'spotify-popularity': 8},
#  {'date': '2024-05-08T00:00:00+00:00',
#   'spotify-streams': 2464,
#   'spotify-popularity': 8},
#  {'date': '2024-05-09T00:00:00+00:00',
#   'spotify-streams': 2470,
#   'spotify-popularity': 8},
#  {'date': '2024-05-10T00:00:00+00:00',
#   'spotify-streams': 2473,
#   'spotify-popularity': 8},
#  {'date': '2024-05-11T00:00:00+00:00',
#   'spotify-streams': 2484,
#   'spotify-popularity': 8},
#  {'date': '2024-05-12T00:00:00+00:00',
#   'spotify-streams': 2484,
#   'spotify-popularity': 8},
#  {'date': '2024-05-13T00:00:00+00:00',
#   'spotify-streams': 2488,
#   'spotify-popularity': 7},
#  {'date': '2024-05-14T00:00:00+00:00',
#   'spotify-streams': 2493,
#   'spotify-popularity': 7},
#  {'date': '2024-05-15T00:00:00+00:00',
#   'spotify-streams': 2495,
#   'spotify-popularity': 7},
#  {'date': '2024-05-16T00:00:00+00:00',
#   'spotify-streams': 2499,
#   'spotify-popularity': 7},
#  {'date': '2024-05-17T00:00:00+00:00',
#   'spotify-streams': 2504,
#   'spotify-popularity': 7},
#  {'date': '2024-05-18T00:00:00+00:00',
#   'spotify-streams': 2507,
#   'spotify-popularity': 7},
#  {'date': '2024-05-19T00:00:00+00:00',
#   'spotify-streams': 2515,
#   'spotify-popularity': 6},
#  {'date': '2024-05-20T00:00:00+00:00',
#   'spotify-streams': 2516,
#   'spotify-popularity': 6},
#  {'date': '2024-05-21T00:00:00+00:00',
#   'spotify-streams': 2520,
#   'spotify-popularity': 6},
#  {'date': '2024-05-22T00:00:00+00:00',
#   'spotify-streams': 2528,
#   'spotify-popularity': 6},
#  {'date': '2024-05-23T00:00:00+00:00',
#   'spotify-streams': 2532,
#   'spotify-popularity': 6},
#  {'date': '2024-05-24T00:00:00+00:00',
#   'spotify-streams': 2537,
#   'spotify-popularity': 6},
#  {'date': '2024-05-25T00:00:00+00:00',
#   'spotify-streams': 2538,
#   'spotify-popularity': 6},
#  {'date': '2024-05-26T00:00:00+00:00',
#   'spotify-streams': 2542,
#   'spotify-popularity': 6},
#  {'date': '2024-05-27T00:00:00+00:00',
#   'spotify-streams': 2547,
#   'spotify-popularity': 5},
#  {'date': '2024-05-28T00:00:00+00:00',
#   'spotify-streams': 2549,
#   'spotify-popularity': 5},
#  {'date': '2024-05-29T00:00:00+00:00',
#   'spotify-streams': 2552,
#   'spotify-popularity': 5},
#  {'date': '2024-05-30T00:00:00+00:00',
#   'spotify-streams': 2557,
#   'spotify-popularity': 5},
#  {'date': '2024-05-31T00:00:00+00:00',
#   'spotify-streams': 2563,
#   'spotify-popularity': 5},
#  {'date': '2024-06-01T00:00:00+00:00',
#   'spotify-streams': 2570,
#   'spotify-popularity': 5},
#  {'date': '2024-06-02T00:00:00+00:00',
#   'spotify-streams': 2575,
#   'spotify-popularity': 5},
#  {'date': '2024-06-03T00:00:00+00:00',
#   'spotify-streams': 2579,
#   'spotify-popularity': 4},
#  {'date': '2024-06-04T00:00:00+00:00',
#   'spotify-streams': 2588,
#   'spotify-popularity': 4},
#  {'date': '2024-06-05T00:00:00+00:00',
#   'spotify-streams': 2593,
#   'spotify-popularity': 4},
#  {'date': '2024-06-06T00:00:00+00:00',
#   'spotify-streams': 2598,
#   'spotify-popularity': 4},
#  {'date': '2024-06-07T00:00:00+00:00',
#   'spotify-streams': 2603,
#   'spotify-popularity': 4},
#  {'date': '2024-06-08T00:00:00+00:00',
#   'spotify-streams': 2608,
#   'spotify-popularity': 4},
#  {'date': '2024-06-09T00:00:00+00:00',
#   'spotify-streams': 2612,
#   'spotify-popularity': 4},
#  {'date': '2024-06-10T00:00:00+00:00',
#   'spotify-streams': 2619,
#   'spotify-popularity': 4},
#  {'date': '2024-06-11T00:00:00+00:00',
#   'spotify-streams': 2622,
#   'spotify-popularity': 2},
#  {'date': '2024-06-12T00:00:00+00:00',
#   'spotify-streams': 2625,
#   'spotify-popularity': 2},
#  {'date': '2024-06-13T00:00:00+00:00',
#   'spotify-streams': 2635,
#   'spotify-popularity': 2},
#  {'date': '2024-06-14T00:00:00+00:00',
#   'spotify-streams': 2639,
#   'spotify-popularity': 2},
#  {'date': '2024-06-15T00:00:00+00:00',
#   'spotify-streams': 2642,
#   'spotify-popularity': 2},
#  {'date': '2024-06-16T00:00:00+00:00',
#   'spotify-streams': 2648,
#   'spotify-popularity': 2},
#  {'date': '2024-06-17T00:00:00+00:00',
#   'spotify-streams': 2650,
#   'spotify-popularity': 2},
#  {'date': '2024-06-18T00:00:00+00:00',
#   'spotify-streams': 2653,
#   'spotify-popularity': 2},
#  {'date': '2024-06-19T00:00:00+00:00',
#   'spotify-streams': 2663,
#   'spotify-popularity': 2},
#  {'date': '2024-06-20T00:00:00+00:00',
#   'spotify-streams': 2666,
#   'spotify-popularity': 2},
#  {'date': '2024-06-21T00:00:00+00:00',
#   'spotify-streams': 2673,
#   'spotify-popularity': 2},
#  {'date': '2024-06-22T00:00:00+00:00',
#   'spotify-streams': 2682,
#   'spotify-popularity': 2},
#  {'date': '2024-06-23T00:00:00+00:00',
#   'spotify-streams': 2685,
#   'spotify-popularity': 2},
#  {'date': '2024-06-24T00:00:00+00:00',
#   'spotify-streams': 2688,
#   'spotify-popularity': 2},
#  {'date': '2024-06-25T00:00:00+00:00',
#   'spotify-streams': 2691,
#   'spotify-popularity': 2},
#  {'date': '2024-06-26T00:00:00+00:00',
#   'spotify-streams': 2699,
#   'spotify-popularity': 2},
#  {'date': '2024-06-27T00:00:00+00:00',
#   'spotify-streams': 2702,
#   'spotify-popularity': 2},
#  {'date': '2024-06-28T00:00:00+00:00',
#   'spotify-streams': 2702,
#   'spotify-popularity': 2},
#  {'date': '2024-06-29T00:00:00+00:00',
#   'spotify-streams': 2703,
#   'spotify-popularity': 2},
#  {'date': '2024-06-30T00:00:00+00:00',
#   'spotify-streams': 2703,
#   'spotify-popularity': 2},
#  {'date': '2024-07-01T00:00:00+00:00',
#   'spotify-streams': 2708,
#   'spotify-popularity': 3},
#  {'date': '2024-07-02T00:00:00+00:00',
#   'spotify-streams': 2716,
#   'spotify-popularity': 3},
#  {'date': '2024-07-03T00:00:00+00:00',
#   'spotify-streams': 2725,
#   'spotify-popularity': 3},
#  {'date': '2024-07-04T00:00:00+00:00',
#   'spotify-streams': 2729,
#   'spotify-popularity': 3},
#  {'date': '2024-07-05T00:00:00+00:00',
#   'spotify-streams': 2734,
#   'spotify-popularity': 3},
#  {'date': '2024-07-06T00:00:00+00:00',
#   'spotify-streams': 2739,
#   'spotify-popularity': 3},
#  {'date': '2024-07-07T00:00:00+00:00',
#   'spotify-streams': 2742,
#   'spotify-popularity': 3},
#  {'date': '2024-07-08T00:00:00+00:00',
#   'spotify-streams': 2747,
#   'spotify-popularity': 3},
#  {'date': '2024-07-09T00:00:00+00:00',
#   'spotify-streams': 2751,
#   'spotify-popularity': 3},
#  {'date': '2024-07-10T00:00:00+00:00',
#   'spotify-streams': 2755,
#   'spotify-popularity': 3},
#  {'date': '2024-07-11T00:00:00+00:00',
#   'spotify-streams': 2757,
#   'spotify-popularity': 3},
#  {'date': '2024-07-12T00:00:00+00:00',
#   'spotify-streams': 2761,
#   'spotify-popularity': 3},
#  {'date': '2024-07-13T00:00:00+00:00',
#   'spotify-streams': 2765,
#   'spotify-popularity': 3},
#  {'date': '2024-07-14T00:00:00+00:00',
#   'spotify-streams': 2768,
#   'spotify-popularity': 3},
#  {'date': '2024-07-15T00:00:00+00:00',
#   'spotify-streams': 2768,
#   'spotify-popularity': 3},
#  {'date': '2024-07-16T00:00:00+00:00',
#   'spotify-streams': 2773,
#   'spotify-popularity': 3},
#  {'date': '2024-07-17T00:00:00+00:00',
#   'spotify-streams': 2776,
#   'spotify-popularity': 3},
#  {'date': '2024-07-18T00:00:00+00:00',
#   'spotify-streams': 2778,
#   'spotify-popularity': 3},
#  {'date': '2024-07-19T00:00:00+00:00',
#   'spotify-streams': 2779,
#   'spotify-popularity': 3},
#  {'date': '2024-07-20T00:00:00+00:00',
#   'spotify-streams': 2786,
#   'spotify-popularity': 3},
#  {'date': '2024-07-21T00:00:00+00:00',
#   'spotify-streams': 2790,
#   'spotify-popularity': 3},
#  {'date': '2024-07-22T00:00:00+00:00',
#   'spotify-streams': 2794,
#   'spotify-popularity': 3},
#  {'date': '2024-07-23T00:00:00+00:00',
#   'spotify-streams': 2798,
#   'spotify-popularity': 3},
#  {'date': '2024-07-24T00:00:00+00:00',
#   'spotify-streams': 2803,
#   'spotify-popularity': 3},
#  {'date': '2024-07-25T00:00:00+00:00',
#   'spotify-streams': 2809,
#   'spotify-popularity': 3},
#  {'date': '2024-07-26T00:00:00+00:00',
#   'spotify-streams': 2811,
#   'spotify-popularity': 3},
#  {'date': '2024-07-27T00:00:00+00:00',
#   'spotify-streams': 2816,
#   'spotify-popularity': 3},
#  {'date': '2024-07-28T00:00:00+00:00',
#   'spotify-streams': 2822,
#   'spotify-popularity': 3},
#  {'date': '2024-07-29T00:00:00+00:00',
#   'spotify-streams': 2826,
#   'spotify-popularity': 3},
#  {'date': '2024-07-30T00:00:00+00:00',
#   'spotify-streams': 2828,
#   'spotify-popularity': 3},
#  {'date': '2024-07-31T00:00:00+00:00',
#   'spotify-streams': 2832,
#   'spotify-popularity': 3},
#  {'date': '2024-08-01T00:00:00+00:00',
#   'spotify-streams': 2833,
#   'spotify-popularity': 3},
#  {'date': '2024-08-02T00:00:00+00:00',
#   'spotify-streams': 2837,
#   'spotify-popularity': 3},
#  {'date': '2024-08-03T00:00:00+00:00',
#   'spotify-streams': 2840,
#   'spotify-popularity': 3},
#  {'date': '2024-08-04T00:00:00+00:00',
#   'spotify-streams': 2843,
#   'spotify-popularity': 3},
#  {'date': '2024-08-05T00:00:00+00:00',
#   'spotify-streams': 2846,
#   'spotify-popularity': 3},
#  {'date': '2024-08-06T00:00:00+00:00',
#   'spotify-streams': 2848,
#   'spotify-popularity': 3},
#  {'date': '2024-08-07T00:00:00+00:00',
#   'spotify-streams': 2853,
#   'spotify-popularity': 3},
#  {'date': '2024-08-08T00:00:00+00:00',
#   'spotify-streams': 2856,
#   'spotify-popularity': 3},
#  {'date': '2024-08-09T00:00:00+00:00',
#   'spotify-streams': 2858,
#   'spotify-popularity': 3},
#  {'date': '2024-08-10T00:00:00+00:00',
#   'spotify-streams': 2861,
#   'spotify-popularity': 3},
#  {'date': '2024-08-11T00:00:00+00:00',
#   'spotify-streams': 2864,
#   'spotify-popularity': 3},
#  {'date': '2024-08-12T00:00:00+00:00',
#   'spotify-streams': 2865,
#   'spotify-popularity': 2},
#  {'date': '2024-08-13T00:00:00+00:00',
#   'spotify-streams': 2869,
#   'spotify-popularity': 2},
#  {'date': '2024-08-14T00:00:00+00:00',
#   'spotify-streams': 2871,
#   'spotify-popularity': 2},
#  {'date': '2024-08-15T00:00:00+00:00',
#   'spotify-streams': 2871,
#   'spotify-popularity': 2},
#  {'date': '2024-08-16T00:00:00+00:00',
#   'spotify-streams': 2874,
#   'spotify-popularity': 2},
#  {'date': '2024-08-17T00:00:00+00:00',
#   'spotify-streams': 2874,
#   'spotify-popularity': 2},
#  {'date': '2024-08-18T00:00:00+00:00',
#   'spotify-streams': 2878,
#   'spotify-popularity': 2},
#  {'date': '2024-08-19T00:00:00+00:00',
#   'spotify-streams': 2881,
#   'spotify-popularity': 2},
#  {'date': '2024-08-20T00:00:00+00:00',
#   'spotify-streams': 2884,
#   'spotify-popularity': 2},
#  {'date': '2024-08-21T00:00:00+00:00',
#   'spotify-streams': 2884,
#   'spotify-popularity': 2},
#  {'date': '2024-08-22T00:00:00+00:00',
#   'spotify-streams': 2886,
#   'spotify-popularity': 2},
#  {'date': '2024-08-23T00:00:00+00:00',
#   'spotify-streams': 2890,
#   'spotify-popularity': 2},
#  {'date': '2024-08-24T00:00:00+00:00',
#   'spotify-streams': 2891,
#   'spotify-popularity': 2},
#  {'date': '2024-08-25T00:00:00+00:00',
#   'spotify-streams': 2892,
#   'spotify-popularity': 2},
#  {'date': '2024-08-26T00:00:00+00:00',
#   'spotify-streams': 2893,
#   'spotify-popularity': 2},
#  {'date': '2024-08-27T00:00:00+00:00',
#   'spotify-streams': 2894,
#   'spotify-popularity': 2},
#  {'date': '2024-08-28T00:00:00+00:00',
#   'spotify-streams': 2898,
#   'spotify-popularity': 2},
#  {'date': '2024-08-29T00:00:00+00:00',
#   'spotify-streams': 2899,
#   'spotify-popularity': 2},
#  {'date': '2024-08-30T00:00:00+00:00',
#   'spotify-streams': 2902,
#   'spotify-popularity': 2},
#  {'date': '2024-08-31T00:00:00+00:00',
#   'spotify-streams': 2905,
#   'spotify-popularity': 2},
#  {'date': '2024-09-01T00:00:00+00:00',
#   'spotify-streams': 2906,
#   'spotify-popularity': 2},
#  {'date': '2024-09-02T00:00:00+00:00',
#   'spotify-streams': 2907,
#   'spotify-popularity': 2},
#  {'date': '2024-09-03T00:00:00+00:00',
#   'spotify-streams': 2908,
#   'spotify-popularity': 2},
#  {'date': '2024-09-04T00:00:00+00:00',
#   'spotify-streams': 2910,
#   'spotify-popularity': 2},
#  {'date': '2024-09-05T00:00:00+00:00',
#   'spotify-streams': 2912,
#   'spotify-popularity': 2},
#  {'date': '2024-09-06T00:00:00+00:00',
#   'spotify-streams': 2913,
#   'spotify-popularity': 2},
#  {'date': '2024-09-07T00:00:00+00:00',
#   'spotify-streams': 2915,
#   'spotify-popularity': 2},
#  {'date': '2024-09-08T00:00:00+00:00',
#   'spotify-streams': 2922,
#   'spotify-popularity': 2},
#  {'date': '2024-09-09T00:00:00+00:00',
#   'spotify-streams': 2931,
#   'spotify-popularity': 2},
#  {'date': '2024-09-10T00:00:00+00:00',
#   'spotify-streams': 2935,
#   'spotify-popularity': 2},
#  {'date': '2024-09-11T00:00:00+00:00',
#   'spotify-streams': 2937,
#   'spotify-popularity': 2},
#  {'date': '2024-09-12T00:00:00+00:00',
#   'spotify-streams': 2942,
#   'spotify-popularity': 2},
#  {'date': '2024-09-13T00:00:00+00:00',
#   'spotify-streams': 2947,
#   'spotify-popularity': 2},
#  {'date': '2024-09-14T00:00:00+00:00',
#   'spotify-streams': 2953,
#   'spotify-popularity': 2},
#  {'date': '2024-09-15T00:00:00+00:00',
#   'spotify-streams': 2958,
#   'spotify-popularity': 2},
#  {'date': '2024-09-16T00:00:00+00:00',
#   'spotify-streams': 2966,
#   'spotify-popularity': 2},
#  {'date': '2024-09-17T00:00:00+00:00',
#   'spotify-streams': 2971,
#   'spotify-popularity': 3},
#  {'date': '2024-09-18T00:00:00+00:00',
#   'spotify-streams': 2984,
#   'spotify-popularity': 3},
#  {'date': '2024-09-19T00:00:00+00:00',
#   'spotify-streams': 3011,
#   'spotify-popularity': 3},
#  {'date': '2024-09-20T00:00:00+00:00',
#   'spotify-streams': 3023,
#   'spotify-popularity': 3},
#  {'date': '2024-09-21T00:00:00+00:00',
#   'spotify-streams': 3032,
#   'spotify-popularity': 3},
#  {'date': '2024-09-22T00:00:00+00:00',
#   'spotify-streams': 3035,
#   'spotify-popularity': 3},
#  {'date': '2024-09-23T00:00:00+00:00',
#   'spotify-streams': 3044,
#   'spotify-popularity': 3},
#  {'date': '2024-09-24T00:00:00+00:00',
#   'spotify-streams': 3051,
#   'spotify-popularity': 3},
#  {'date': '2024-09-25T00:00:00+00:00',
#   'spotify-streams': 3055,
#   'spotify-popularity': 4},
#  {'date': '2024-09-26T00:00:00+00:00',
#   'spotify-streams': 3060,
#   'spotify-popularity': 4},
#  {'date': '2024-09-27T00:00:00+00:00',
#   'spotify-streams': 3061,
#   'spotify-popularity': 4},
#  {'date': '2024-09-28T00:00:00+00:00',
#   'spotify-streams': 3065,
#   'spotify-popularity': 4},
#  {'date': '2024-09-29T00:00:00+00:00',
#   'spotify-streams': 3071,
#   'spotify-popularity': 4},
#  {'date': '2024-09-30T00:00:00+00:00',
#   'spotify-streams': 3078,
#   'spotify-popularity': 4},
#  {'date': '2024-10-01T00:00:00+00:00',
#   'spotify-streams': 3091,
#   'spotify-popularity': 4},
#  {'date': '2024-10-02T00:00:00+00:00',
#   'spotify-streams': 3092,
#   'spotify-popularity': 4},
#  {'date': '2024-10-03T00:00:00+00:00',
#   'spotify-streams': 3099,
#   'spotify-popularity': 3},
#  {'date': '2024-10-04T00:00:00+00:00',
#   'spotify-streams': 3105,
#   'spotify-popularity': 3},
#  {'date': '2024-10-05T00:00:00+00:00',
#   'spotify-streams': 3113,
#   'spotify-popularity': 3},
#  {'date': '2024-10-06T00:00:00+00:00',
#   'spotify-streams': 3124,
#   'spotify-popularity': 3},
#  {'date': '2024-10-07T00:00:00+00:00',
#   'spotify-streams': 3129,
#   'spotify-popularity': 3},
#  {'date': '2024-10-08T00:00:00+00:00',
#   'spotify-streams': 3135,
#   'spotify-popularity': 3},
#  {'date': '2024-10-09T00:00:00+00:00',
#   'spotify-streams': 3143,
#   'spotify-popularity': 4},
#  {'date': '2024-10-10T00:00:00+00:00',
#   'spotify-streams': 3148,
#   'spotify-popularity': 4},
#  {'date': '2024-10-11T00:00:00+00:00',
#   'spotify-streams': 3149,
#   'spotify-popularity': 4},
#  {'date': '2024-10-12T00:00:00+00:00',
#   'spotify-streams': 3150,
#   'spotify-popularity': 4},
#  {'date': '2024-10-13T00:00:00+00:00',
#   'spotify-streams': 3153,
#   'spotify-popularity': 4},
#  {'date': '2024-10-14T00:00:00+00:00',
#   'spotify-streams': 3158,
#   'spotify-popularity': 4},
#  {'date': '2024-10-15T00:00:00+00:00',
#   'spotify-streams': 3168,
#   'spotify-popularity': 3},
#  {'date': '2024-10-16T00:00:00+00:00',
#   'spotify-streams': 3171,
#   'spotify-popularity': 3},
#  {'date': '2024-10-17T00:00:00+00:00',
#   'spotify-streams': 3179,
#   'spotify-popularity': 3},
#  {'date': '2024-10-18T00:00:00+00:00',
#   'spotify-streams': 3182,
#   'spotify-popularity': 3},
#  {'date': '2024-10-19T00:00:00+00:00',
#   'spotify-streams': 3185,
#   'spotify-popularity': 3},
#  {'date': '2024-10-20T00:00:00+00:00',
#   'spotify-streams': 3186,
#   'spotify-popularity': 3},
#  {'date': '2024-10-21T00:00:00+00:00',
#   'spotify-streams': 3190,
#   'spotify-popularity': 3},
#  {'date': '2024-10-22T00:00:00+00:00',
#   'spotify-streams': 3195,
#   'spotify-popularity': 3},
#  {'date': '2024-10-23T00:00:00+00:00',
#   'spotify-streams': 3198,
#   'spotify-popularity': 3},
#  {'date': '2024-10-24T00:00:00+00:00',
#   'spotify-streams': 3202,
#   'spotify-popularity': 3},
#  {'date': '2024-10-25T00:00:00+00:00',
#   'spotify-streams': 3204,
#   'spotify-popularity': 3},
#  {'date': '2024-10-26T00:00:00+00:00',
#   'spotify-streams': 3208,
#   'spotify-popularity': 3},
#  {'date': '2024-10-27T00:00:00+00:00',
#   'spotify-streams': 3213,
#   'spotify-popularity': 3},
#  {'date': '2024-10-28T00:00:00+00:00',
#   'spotify-streams': 3219,
#   'spotify-popularity': 3},
#  {'date': '2024-10-29T00:00:00+00:00',
#   'spotify-streams': 3222,
#   'spotify-popularity': 3},
#  {'date': '2024-10-30T00:00:00+00:00',
#   'spotify-streams': 3225,
#   'spotify-popularity': 3},
#  {'date': '2024-10-31T00:00:00+00:00',
#   'spotify-streams': 3229,
#   'spotify-popularity': 3},
#  {'date': '2024-11-01T00:00:00+00:00',
#   'spotify-streams': 3231,
#   'spotify-popularity': 3},
#  {'date': '2024-11-02T00:00:00+00:00',
#   'spotify-streams': 3233,
#   'spotify-popularity': 3},
#  {'date': '2024-11-03T00:00:00+00:00',
#   'spotify-streams': 3236,
#   'spotify-popularity': 3},
#  {'date': '2024-11-04T00:00:00+00:00',
#   'spotify-streams': 3239,
#   'spotify-popularity': 2},
#  {'date': '2024-11-05T00:00:00+00:00',
#   'spotify-streams': 3239,
#   'spotify-popularity': 2},
#  {'date': '2024-11-06T00:00:00+00:00',
#   'spotify-streams': 3245,
#   'spotify-popularity': 2},
#  {'date': '2024-11-07T00:00:00+00:00',
#   'spotify-streams': 3247,
#   'spotify-popularity': 2},
#  {'date': '2024-11-08T00:00:00+00:00',
#   'spotify-streams': 3251,
#   'spotify-popularity': 2},
#  {'date': '2024-11-09T00:00:00+00:00',
#   'spotify-streams': 3251,
#   'spotify-popularity': 2},
#  {'date': '2024-11-10T00:00:00+00:00',
#   'spotify-streams': 3256,
#   'spotify-popularity': 2},
#  {'date': '2024-11-11T00:00:00+00:00',
#   'spotify-streams': 3279,
#   'spotify-popularity': 2},
#  {'date': '2024-11-12T00:00:00+00:00',
#   'spotify-streams': 3281,
#   'spotify-popularity': 2},
#  {'date': '2024-11-13T00:00:00+00:00',
#   'spotify-streams': 3284,
#   'spotify-popularity': 2},
#  {'date': '2024-11-14T00:00:00+00:00',
#   'spotify-streams': 3285,
#   'spotify-popularity': 2},
#  {'date': '2024-11-15T00:00:00+00:00',
#   'spotify-streams': 3287,
#   'spotify-popularity': 2},
#  {'date': '2024-11-16T00:00:00+00:00',
#   'spotify-streams': 3290,
#   'spotify-popularity': 2},
#  {'date': '2024-11-17T00:00:00+00:00',
#   'spotify-streams': 3291,
#   'spotify-popularity': 2},
#  {'date': '2024-11-18T00:00:00+00:00',
#   'spotify-streams': 3292,
#   'spotify-popularity': 2},
#  {'date': '2024-11-19T00:00:00+00:00',
#   'spotify-streams': 3294,
#   'spotify-popularity': 2},
#  {'date': '2024-11-20T00:00:00+00:00',
#   'spotify-streams': 3296,
#   'spotify-popularity': 2},
#  {'date': '2024-11-21T00:00:00+00:00',
#   'spotify-streams': 3301,
#   'spotify-popularity': 2},
#  {'date': '2024-11-22T00:00:00+00:00',
#   'spotify-streams': 3307,
#   'spotify-popularity': 2},
#  {'date': '2024-11-23T00:00:00+00:00',
#   'spotify-streams': 3311,
#   'spotify-popularity': 2},
#  {'date': '2024-11-24T00:00:00+00:00',
#   'spotify-streams': 3313,
#   'spotify-popularity': 2},
#  {'date': '2024-11-25T00:00:00+00:00',
#   'spotify-streams': 3319,
#   'spotify-popularity': 2},
#  {'date': '2024-11-26T00:00:00+00:00',
#   'spotify-streams': 3320,
#   'spotify-popularity': 2},
#  {'date': '2024-11-27T00:00:00+00:00',
#   'spotify-streams': 3320,
#   'spotify-popularity': 2},
#  {'date': '2024-11-28T00:00:00+00:00',
#   'spotify-streams': 3322,
#   'spotify-popularity': 2},
#  {'date': '2024-11-29T00:00:00+00:00',
#   'spotify-streams': 3326,
#   'spotify-popularity': 2},
#  {'date': '2024-11-30T00:00:00+00:00',
#   'spotify-streams': 3329,
#   'spotify-popularity': 2},
#  {'date': '2024-12-01T00:00:00+00:00',
#   'spotify-streams': 3332,
#   'spotify-popularity': 2},
#  {'date': '2024-12-02T00:00:00+00:00',
#   'spotify-streams': 3335,
#   'spotify-popularity': 2},
#  {'date': '2024-12-03T00:00:00+00:00',
#   'spotify-streams': 3340,
#   'spotify-popularity': 2},
#  {'date': '2024-12-04T00:00:00+00:00',
#   'spotify-streams': 3343,
#   'spotify-popularity': 2},
#  {'date': '2024-12-05T00:00:00+00:00',
#   'spotify-streams': 3345,
#   'spotify-popularity': 2},
#  {'date': '2024-12-06T00:00:00+00:00',
#   'spotify-streams': 3351,
#   'spotify-popularity': 2},
#  {'date': '2024-12-07T00:00:00+00:00',
#   'spotify-streams': 3355,
#   'spotify-popularity': 2},
#  {'date': '2024-12-08T00:00:00+00:00',
#   'spotify-streams': 3359,
#   'spotify-popularity': 2},
#  {'date': '2024-12-09T00:00:00+00:00',
#   'spotify-streams': 3361,
#   'spotify-popularity': 2},
#  {'date': '2024-12-10T00:00:00+00:00',
#   'spotify-streams': 3364,
#   'spotify-popularity': 2},
#  {'date': '2024-12-11T00:00:00+00:00',
#   'spotify-streams': 3366,
#   'spotify-popularity': 2},
#  {'date': '2024-12-12T00:00:00+00:00',
#   'spotify-streams': 3370,
#   'spotify-popularity': 2},
#  {'date': '2024-12-13T00:00:00+00:00',
#   'spotify-streams': 3372,
#   'spotify-popularity': 2},
#  {'date': '2024-12-14T00:00:00+00:00',
#   'spotify-streams': 3375,
#   'spotify-popularity': 2},
#  {'date': '2024-12-15T00:00:00+00:00',
#   'spotify-streams': 3379,
#   'spotify-popularity': 2},
#  {'date': '2024-12-16T00:00:00+00:00',
#   'spotify-streams': 3379,
#   'spotify-popularity': 2},
#  {'date': '2024-12-17T00:00:00+00:00',
#   'spotify-streams': 3384,
#   'spotify-popularity': 2},
#  {'date': '2024-12-18T00:00:00+00:00',
#   'spotify-streams': 3388,
#   'spotify-popularity': 2},
#  {'date': '2024-12-19T00:00:00+00:00',
#   'spotify-streams': 3390,
#   'spotify-popularity': 2},
#  {'date': '2024-12-20T00:00:00+00:00',
#   'spotify-streams': 3395,
#   'spotify-popularity': 2},
#  {'date': '2024-12-21T00:00:00+00:00',
#   'spotify-streams': 3400,
#   'spotify-popularity': 2},
#  {'date': '2024-12-22T00:00:00+00:00',
#   'spotify-streams': 3403,
#   'spotify-popularity': 2},
#  {'date': '2024-12-23T00:00:00+00:00',
#   'spotify-streams': 3413,
#   'spotify-popularity': 2},
#  {'date': '2024-12-24T00:00:00+00:00',
#   'spotify-streams': 3421,
#   'spotify-popularity': 2},
#  {'date': '2024-12-25T00:00:00+00:00',
#   'spotify-streams': 3431,
#   'spotify-popularity': 2},
#  {'date': '2024-12-26T00:00:00+00:00',
#   'spotify-streams': 3435,
#   'spotify-popularity': 2},
#  {'date': '2024-12-27T00:00:00+00:00',
#   'spotify-streams': 3435,
#   'spotify-popularity': 2},
#  {'date': '2024-12-28T00:00:00+00:00',
#   'spotify-streams': 3437,
#   'spotify-popularity': 2},
#  {'date': '2024-12-29T00:00:00+00:00',
#   'spotify-streams': 3442,
#   'spotify-popularity': 2},
#  {'date': '2024-12-30T00:00:00+00:00',
#   'spotify-streams': 3447,
#   'spotify-popularity': 2},
#  {'date': '2024-12-31T00:00:00+00:00',
#   'spotify-streams': 3454,
#   'spotify-popularity': 2},
#  {'date': '2025-01-01T00:00:00+00:00',
#   'spotify-streams': 3462,
#   'spotify-popularity': 2},
#  {'date': '2025-01-02T00:00:00+00:00',
#   'spotify-streams': 3464,
#   'spotify-popularity': 2},
#  {'date': '2025-01-03T00:00:00+00:00',
#   'spotify-streams': 3466,
#   'spotify-popularity': 2},
#  {'date': '2025-01-04T00:00:00+00:00',
#   'spotify-streams': 3470,
#   'spotify-popularity': 2},
#  {'date': '2025-01-05T00:00:00+00:00',
#   'spotify-streams': 3473,
#   'spotify-popularity': 2},
#  {'date': '2025-01-06T00:00:00+00:00',
#   'spotify-streams': 3474,
#   'spotify-popularity': 2},
#  {'date': '2025-01-07T00:00:00+00:00',
#   'spotify-streams': 3475,
#   'spotify-popularity': 2},
#  {'date': '2025-01-08T00:00:00+00:00',
#   'spotify-streams': 3479,
#   'spotify-popularity': 2},
#  {'date': '2025-01-09T00:00:00+00:00',
#   'spotify-streams': 3481,
#   'spotify-popularity': 2},
#  {'date': '2025-01-10T00:00:00+00:00',
#   'spotify-streams': 3486,
#   'spotify-popularity': 2},
#  {'date': '2025-01-11T00:00:00+00:00',
#   'spotify-streams': 3489,
#   'spotify-popularity': 2},
#  {'date': '2025-01-12T00:00:00+00:00',
#   'spotify-streams': 3496,
#   'spotify-popularity': 2},
#  {'date': '2025-01-13T00:00:00+00:00',
#   'spotify-streams': 3499,
#   'spotify-popularity': 2},
#  {'date': '2025-01-14T00:00:00+00:00',
#   'spotify-streams': 3502,
#   'spotify-popularity': 2},
#  {'date': '2025-01-15T00:00:00+00:00',
#   'spotify-streams': 3504,
#   'spotify-popularity': 2},
#  {'date': '2025-01-16T00:00:00+00:00',
#   'spotify-streams': 3507,
#   'spotify-popularity': 2},
#  {'date': '2025-01-17T00:00:00+00:00',
#   'spotify-streams': 3508,
#   'spotify-popularity': 2},
#  {'date': '2025-01-18T00:00:00+00:00',
#   'spotify-streams': 3515,
#   'spotify-popularity': 2},
#  {'date': '2025-01-19T00:00:00+00:00',
#   'spotify-streams': 3519,
#   'spotify-popularity': 2},
#  {'date': '2025-01-20T00:00:00+00:00',
#   'spotify-streams': 3522,
#   'spotify-popularity': 2},
#  {'date': '2025-01-21T00:00:00+00:00',
#   'spotify-streams': 3529,
#   'spotify-popularity': 2},
#  {'date': '2025-01-22T00:00:00+00:00',
#   'spotify-streams': 3530,
#   'spotify-popularity': 2},
#  {'date': '2025-01-23T00:00:00+00:00',
#   'spotify-streams': 3532,
#   'spotify-popularity': 2},
#  {'date': '2025-01-24T00:00:00+00:00',
#   'spotify-streams': 3534,
#   'spotify-popularity': 2},
#  {'date': '2025-01-25T00:00:00+00:00',
#   'spotify-streams': 3535,
#   'spotify-popularity': 2},
#  {'date': '2025-01-26T00:00:00+00:00',
#   'spotify-streams': 3541,
#   'spotify-popularity': 2},
#  {'date': '2025-01-27T00:00:00+00:00',
#   'spotify-streams': 3548,
#   'spotify-popularity': 2},
#  {'date': '2025-01-28T00:00:00+00:00',
#   'spotify-streams': 3550,
#   'spotify-popularity': 2},
#  {'date': '2025-01-29T00:00:00+00:00',
#   'spotify-streams': 3551,
#   'spotify-popularity': 2},
#  {'date': '2025-01-30T00:00:00+00:00',
#   'spotify-streams': 3557,
#   'spotify-popularity': 2},
#  {'date': '2025-01-31T00:00:00+00:00',
#   'spotify-streams': 3560,
#   'spotify-popularity': 2},
#  {'date': '2025-02-01T00:00:00+00:00',
#   'spotify-streams': 3563,
#   'spotify-popularity': 2},
#  {'date': '2025-02-02T00:00:00+00:00',
#   'spotify-streams': 3566,
#   'spotify-popularity': 2},
#  {'date': '2025-02-03T00:00:00+00:00',
#   'spotify-streams': 3572,
#   'spotify-popularity': 2},
#  {'date': '2025-02-04T00:00:00+00:00',
#   'spotify-streams': 3576,
#   'spotify-popularity': 2},
#  {'date': '2025-02-05T00:00:00+00:00',
#   'spotify-streams': 3579,
#   'spotify-popularity': 2},
#  {'date': '2025-02-06T00:00:00+00:00',
#   'spotify-streams': 3584,
#   'spotify-popularity': 2},
#  {'date': '2025-02-07T00:00:00+00:00',
#   'spotify-streams': 3584,
#   'spotify-popularity': 2},
#  {'date': '2025-02-08T00:00:00+00:00',
#   'spotify-streams': 3588,
#   'spotify-popularity': 2},
#  {'date': '2025-02-09T00:00:00+00:00',
#   'spotify-streams': 3590,
#   'spotify-popularity': 2},
#  {'date': '2025-02-10T00:00:00+00:00',
#   'spotify-streams': 3594,
#   'spotify-popularity': 2},
#  {'date': '2025-02-11T00:00:00+00:00',
#   'spotify-streams': 3596,
#   'spotify-popularity': 2},
#  {'date': '2025-02-12T00:00:00+00:00',
#   'spotify-streams': 3600,
#   'spotify-popularity': 2},
#  {'date': '2025-02-13T00:00:00+00:00',
#   'spotify-streams': 3603,
#   'spotify-popularity': 2},
#  {'date': '2025-02-14T00:00:00+00:00',
#   'spotify-streams': 3605,
#   'spotify-popularity': 2},
#  {'date': '2025-02-15T00:00:00+00:00',
#   'spotify-streams': 3607,
#   'spotify-popularity': 2},
#  {'date': '2025-02-16T00:00:00+00:00',
#   'spotify-streams': 3607,
#   'spotify-popularity': 2},
#  {'date': '2025-02-17T00:00:00+00:00',
#   'spotify-streams': 3609,
#   'spotify-popularity': 2},
#  {'date': '2025-02-18T00:00:00+00:00',
#   'spotify-streams': 3613,
#   'spotify-popularity': 2},
#  {'date': '2025-02-19T00:00:00+00:00',
#   'spotify-streams': 3613,
#   'spotify-popularity': 2},
#  {'date': '2025-02-20T00:00:00+00:00',
#   'spotify-streams': 3617,
#   'spotify-popularity': 2},
#  {'date': '2025-02-21T00:00:00+00:00',
#   'spotify-streams': 3617,
#   'spotify-popularity': 2},
#  {'date': '2025-02-22T00:00:00+00:00',
#   'spotify-streams': 3620,
#   'spotify-popularity': 2},
#  {'date': '2025-02-23T00:00:00+00:00',
#   'spotify-streams': 3623,
#   'spotify-popularity': 1},
#  {'date': '2025-02-24T00:00:00+00:00',
#   'spotify-streams': 3625,
#   'spotify-popularity': 1},
#  {'date': '2025-02-25T00:00:00+00:00',
#   'spotify-streams': 3628,
#   'spotify-popularity': 1},
#  {'date': '2025-02-26T00:00:00+00:00',
#   'spotify-streams': 3630,
#   'spotify-popularity': 1},
#  {'date': '2025-02-27T00:00:00+00:00',
#   'spotify-streams': 3633,
#   'spotify-popularity': 1},
#  {'date': '2025-02-28T00:00:00+00:00',
#   'spotify-streams': 3641,
#   'spotify-popularity': 1},
#  {'date': '2025-03-01T00:00:00+00:00',
#   'spotify-streams': 3650,
#   'spotify-popularity': 1},
#  {'date': '2025-03-02T00:00:00+00:00',
#   'spotify-streams': 3659,
#   'spotify-popularity': 1},
#  {'date': '2025-03-03T00:00:00+00:00',
#   'spotify-streams': 3664,
#   'spotify-popularity': 1},
#  {'date': '2025-03-04T00:00:00+00:00',
#   'spotify-streams': 3670,
#   'spotify-popularity': 1},
#  {'date': '2025-03-05T00:00:00+00:00',
#   'spotify-streams': 3675,
#   'spotify-popularity': 1},
#  {'date': '2025-03-06T00:00:00+00:00',
#   'spotify-streams': 3681,
#   'spotify-popularity': 1},
#  {'date': '2025-03-07T00:00:00+00:00',
#   'spotify-streams': 3684,
#   'spotify-popularity': 1},
#  {'date': '2025-03-08T00:00:00+00:00',
#   'spotify-streams': 3689,
#   'spotify-popularity': 1},
#  {'date': '2025-03-09T00:00:00+00:00',
#   'spotify-streams': 3694,
#   'spotify-popularity': 3},
#  {'date': '2025-03-10T00:00:00+00:00',
#   'spotify-streams': 3699,
#   'spotify-popularity': 3},
#  {'date': '2025-03-11T00:00:00+00:00',
#   'spotify-streams': 3702,
#   'spotify-popularity': 3},
#  {'date': '2025-03-12T00:00:00+00:00',
#   'spotify-streams': 3710,
#   'spotify-popularity': 3},
#  {'date': '2025-03-13T00:00:00+00:00',
#   'spotify-streams': 3711,
#   'spotify-popularity': 3},
#  {'date': '2025-03-14T00:00:00+00:00',
#   'spotify-streams': 3718,
#   'spotify-popularity': 3},
#  {'date': '2025-03-15T00:00:00+00:00',
#   'spotify-streams': 3722,
#   'spotify-popularity': 3},
#  {'date': '2025-03-16T00:00:00+00:00',
#   'spotify-streams': 3725,
#   'spotify-popularity': 3},
#  {'date': '2025-03-17T00:00:00+00:00',
#   'spotify-streams': 3729,
#   'spotify-popularity': 3},
#  {'date': '2025-03-18T00:00:00+00:00',
#   'spotify-streams': 3734,
#   'spotify-popularity': 3},
#  {'date': '2025-03-19T00:00:00+00:00',
#   'spotify-streams': 3735,
#   'spotify-popularity': 3},
#  {'date': '2025-03-20T00:00:00+00:00',
#   'spotify-streams': 3737,
#   'spotify-popularity': 3},
#  {'date': '2025-03-21T00:00:00+00:00',
#   'spotify-streams': 3740,
#   'spotify-popularity': 3},
#  {'date': '2025-03-22T00:00:00+00:00',
#   'spotify-streams': 3743,
#   'spotify-popularity': 3},
#  {'date': '2025-03-23T00:00:00+00:00',
#   'spotify-streams': 3745,
#   'spotify-popularity': 3},
#  {'date': '2025-03-24T00:00:00+00:00',
#   'spotify-streams': 3749,
#   'spotify-popularity': 3},
#  {'date': '2025-03-25T00:00:00+00:00',
#   'spotify-streams': 3751,
#   'spotify-popularity': 3},
#  {'date': '2025-03-26T00:00:00+00:00',
#   'spotify-streams': 3755,
#   'spotify-popularity': 3},
#  {'date': '2025-03-27T00:00:00+00:00',
#   'spotify-streams': 3759,
#   'spotify-popularity': 3},
#  {'date': '2025-03-28T00:00:00+00:00',
#   'spotify-streams': 3760,
#   'spotify-popularity': 3},
#  {'date': '2025-03-29T00:00:00+00:00',
#   'spotify-streams': 3762,
#   'spotify-popularity': 3},
#  {'date': '2025-03-30T00:00:00+00:00',
#   'spotify-streams': 3773,
#   'spotify-popularity': 3},
#  {'date': '2025-03-31T00:00:00+00:00',
#   'spotify-streams': 3777,
#   'spotify-popularity': 3},
#  {'date': '2025-04-01T00:00:00+00:00',
#   'spotify-streams': 3779,
#   'spotify-popularity': 3},
#  {'date': '2025-04-02T00:00:00+00:00',
#   'spotify-streams': 3781,
#   'spotify-popularity': 3},
#  {'date': '2025-04-03T00:00:00+00:00',
#   'spotify-streams': 3784,
#   'spotify-popularity': 3},
#  {'date': '2025-04-04T00:00:00+00:00',
#   'spotify-streams': 3786,
#   'spotify-popularity': 3},
#  {'date': '2025-04-05T00:00:00+00:00',
#   'spotify-streams': 3787,
#   'spotify-popularity': 3},
#  {'date': '2025-04-06T00:00:00+00:00',
#   'spotify-streams': 3789,
#   'spotify-popularity': 3},
#  {'date': '2025-04-07T00:00:00+00:00',
#   'spotify-streams': 3793,
#   'spotify-popularity': 3},
#  {'date': '2025-04-08T00:00:00+00:00',
#   'spotify-streams': 3796,
#   'spotify-popularity': 3},
#  {'date': '2025-04-09T00:00:00+00:00',
#   'spotify-streams': 3799,
#   'spotify-popularity': 3},
#  {'date': '2025-04-10T00:00:00+00:00',
#   'spotify-streams': 3802,
#   'spotify-popularity': 3},
#  {'date': '2025-04-11T00:00:00+00:00',
#   'spotify-streams': 3802,
#   'spotify-popularity': 3},
#  {'date': '2025-04-12T00:00:00+00:00',
#   'spotify-streams': 3803,
#   'spotify-popularity': 3},
#  {'date': '2025-04-13T00:00:00+00:00',
#   'spotify-streams': 3808,
#   'spotify-popularity': 3},
#  {'date': '2025-04-14T00:00:00+00:00',
#   'spotify-streams': 3810,
#   'spotify-popularity': 3},
#  {'date': '2025-04-15T00:00:00+00:00',
#   'spotify-streams': 3811,
#   'spotify-popularity': 3},
#  {'date': '2025-04-16T00:00:00+00:00',
#   'spotify-streams': 3813,
#   'spotify-popularity': 3},
#  {'date': '2025-04-17T00:00:00+00:00',
#   'spotify-streams': 3817,
#   'spotify-popularity': 3},
#  {'date': '2025-04-18T00:00:00+00:00',
#   'spotify-streams': 3820,
#   'spotify-popularity': 3},
#  {'date': '2025-04-19T00:00:00+00:00',
#   'spotify-streams': 3823,
#   'spotify-popularity': 3},
#  {'date': '2025-04-20T00:00:00+00:00',
#   'spotify-streams': 3829,
#   'spotify-popularity': 3},
#  {'date': '2025-04-21T00:00:00+00:00',
#   'spotify-streams': 3834,
#   'spotify-popularity': 3},
#  {'date': '2025-04-22T00:00:00+00:00',
#   'spotify-streams': 3838,
#   'spotify-popularity': 3},
#  {'date': '2025-04-23T00:00:00+00:00',
#   'spotify-streams': 3838,
#   'spotify-popularity': 3},
#  {'date': '2025-04-24T00:00:00+00:00',
#   'spotify-streams': 3840,
#   'spotify-popularity': 3},
#  {'date': '2025-04-25T00:00:00+00:00',
#   'spotify-streams': 3842,
#   'spotify-popularity': 3},
#  {'date': '2025-04-26T00:00:00+00:00',
#   'spotify-streams': 3847,
#   'spotify-popularity': 3},
#  {'date': '2025-04-27T00:00:00+00:00',
#   'spotify-streams': 3849,
#   'spotify-popularity': 3},
#  {'date': '2025-04-28T00:00:00+00:00',
#   'spotify-streams': 3852,
#   'spotify-popularity': 3},
#  {'date': '2025-04-29T00:00:00+00:00',
#   'spotify-streams': 3855,
#   'spotify-popularity': 3},
#  {'date': '2025-04-30T00:00:00+00:00',
#   'spotify-streams': 3858,
#   'spotify-popularity': 3},
#  {'date': '2025-05-01T00:00:00+00:00',
#   'spotify-streams': 3859,
#   'spotify-popularity': 3},
#  {'date': '2025-05-02T00:00:00+00:00',
#   'spotify-streams': 3862,
#   'spotify-popularity': 3},
#  {'date': '2025-05-03T00:00:00+00:00',
#   'spotify-streams': 3867,
#   'spotify-popularity': 3},
#  {'date': '2025-05-04T00:00:00+00:00',
#   'spotify-streams': 3870,
#   'spotify-popularity': 3},
#  {'date': '2025-05-05T00:00:00+00:00',
#   'spotify-streams': 3873,
#   'spotify-popularity': 3},
#  {'date': '2025-05-06T00:00:00+00:00',
#   'spotify-streams': 3877,
#   'spotify-popularity': 3},
#  {'date': '2025-05-07T00:00:00+00:00',
#   'spotify-streams': 3886,
#   'spotify-popularity': 3},
#  {'date': '2025-05-08T00:00:00+00:00',
#   'spotify-streams': 3887,
#   'spotify-popularity': 3},
#  {'date': '2025-05-09T00:00:00+00:00',
#   'spotify-streams': 3891,
#   'spotify-popularity': 3},
#  {'date': '2025-05-10T00:00:00+00:00',
#   'spotify-streams': 3892,
#   'spotify-popularity': 3},
#  {'date': '2025-05-11T00:00:00+00:00',
#   'spotify-streams': 3897,
#   'spotify-popularity': 3},
#  {'date': '2025-05-12T00:00:00+00:00',
#   'spotify-streams': 3899,
#   'spotify-popularity': 3},
#  {'date': '2025-05-13T00:00:00+00:00',
#   'spotify-streams': 3903,
#   'spotify-popularity': 3},
#  {'date': '2025-05-14T00:00:00+00:00',
#   'spotify-streams': 3905,
#   'spotify-popularity': 3},
#  {'date': '2025-05-15T00:00:00+00:00',
#   'spotify-streams': 3914,
#   'spotify-popularity': 3},
#  {'date': '2025-05-16T00:00:00+00:00',
#   'spotify-streams': 3919,
#   'spotify-popularity': 3},
#  {'date': '2025-05-17T00:00:00+00:00',
#   'spotify-streams': 3925,
#   'spotify-popularity': 3},
#  {'date': '2025-05-18T00:00:00+00:00',
#   'spotify-streams': 3928,
#   'spotify-popularity': 3},
#  {'date': '2025-05-19T00:00:00+00:00',
#   'spotify-streams': 3949,
#   'spotify-popularity': 3}]

# %%
# discovery of summaries structure
json.loads(df['summaries'][0])
# Out:
# {'spotify-streams': {'value': 3949,
#   'metric': 'spotify-streams',
#   'periods': {'1w': {'evolution': 50,
#     'comparedDate': '2025-05-12T00:00:00+00:00',
#     'comparedValue': 3899,
#     'percentEvolution': 1.2823800974608874},
#    '1y': {'evolution': 1434,
#     'comparedDate': '2024-05-19T00:00:00+00:00',
#     'comparedValue': 2515,
#     'percentEvolution': 57.017892644135195},
#    '6m': {'evolution': 657,
#     'comparedDate': '2024-11-18T00:00:00+00:00',
#     'comparedValue': 3292,
#     'percentEvolution': 19.957472660996356},
#    '28d': {'evolution': 115,
#     'comparedDate': '2025-04-21T00:00:00+00:00',
#     'comparedValue': 3834,
#     'percentEvolution': 2.9994783515910277},
#    'all': {'evolution': 1551,
#     'comparedDate': '2024-04-29T00:00:00+00:00',
#     'comparedValue': 2398,
#     'percentEvolution': 64.6788990825688}},
#   'lastDataPointDate': '2025-05-19T00:00:00+00:00',
#   'firstDataPointDate': '2024-04-29T00:00:00+00:00'},
#  'spotify-popularity': {'value': 3,
#   'metric': 'spotify-popularity',
#   'periods': {'1w': {'evolution': 0,
#     'comparedDate': '2025-05-12T00:00:00+00:00',
#     'comparedValue': 3,
#     'percentEvolution': 0},
#    '1y': {'evolution': -3,
#     'comparedDate': '2024-05-19T00:00:00+00:00',
#     'comparedValue': 6,
#     'percentEvolution': -50},
#    '6m': {'evolution': 1,
#     'comparedDate': '2024-11-18T00:00:00+00:00',
#     'comparedValue': 2,
#     'percentEvolution': 50},
#    '28d': {'evolution': 0,
#     'comparedDate': '2025-04-21T00:00:00+00:00',
#     'comparedValue': 3,
#     'percentEvolution': 0},
#    'all': {'evolution': -5,
#     'comparedDate': '2024-04-29T00:00:00+00:00',
#     'comparedValue': 8,
#     'percentEvolution': -62.5}},
#   'lastDataPointDate': '2025-05-19T00:00:00+00:00',
#   'firstDataPointDate': '2024-04-29T00:00:00+00:00'}}

# %% [markdown]
# ### Conception of the ERD
# The ERD is available in the following link : https://app.eraser.io/workspace/zGdBMSC0RzIjWtiEtCWE?origin=share and in CER 1.0

# %% [markdown]
# ### PostgreSQL connection et data insertion
# The structure of the database is created and available in the dump_pr-data.sql file

# %%
# create a reusable connection
# note : change password and database name for your configuration
engine = create_engine('postgresql://postgres:75010@localhost:5432/Base_for_Music_Assessment')

# %% [markdown]
# ##### Artist

# %%
artists = df['artist'].astype(str)
new_artists = []
# split featuring artists
for artist in artists:
    if ' & ' in artist:
        parts = [part for part in artist.split(' & ')]
        new_artists.extend(parts)
    else:
        new_artists.append(artist)
# set of unique artist name 
artists = set(new_artists)
# insertion
df_insert = pd.DataFrame(artists, columns=['name'])
df_insert.to_sql('artist', engine, if_exists='append', index=False)
# Out:
# 802

# %% [markdown]
# ##### Song

# %%
# rename columns to correspond the database columns
df_insert = df[['song_id', 'title', 'release_date', 'image_url']].rename(columns={
    'song_id': 'id',
    'title': 'name',
    'release_date': 'release',
    'image_url': 'image'
})
# drop duplicate songs
df_insert = df_insert.drop_duplicates(subset=['id'])
# format to datetime
df_insert['release'] = pd.to_datetime(df_insert['release'], errors='coerce')
# replace too old date for postgresql and add UTC information
df_insert.loc[df_insert['release'] < pd.Timestamp('1900-01-01').tz_localize('UTC'), 'release'] = pd.Timestamp('1901-01-01').tz_localize('UTC')
# insertion
df_insert.to_sql('song', engine, if_exists='append', index=False)
# Out:
# 290

# %% [markdown]
# ##### Song_actor

# %%
df_temp = df[['song_id', 'artist']]
df_temp = df_temp.drop_duplicates(subset=['song_id'])
song_actor = []
for song_id, artist in df_temp[['song_id', 'artist']].astype(str).values:
    if ' & ' in artist:
        parts = [part for part in artist.split(' & ')]
        for part in parts:
            song_actor.append([song_id,part])
    else:
        song_actor.append([song_id,artist])
df_temp1 = pd.DataFrame(song_actor, columns=['song_id', 'artist'])
df_artist = pd.DataFrame(pd.read_sql('SELECT * FROM artist', engine), columns=['id', 'name'])
df_artist['name'] = df_artist['name'].apply(lambda col: col.strip())
df_insert = df_temp1.merge(df_artist, how='left', left_on='artist', right_on='name')
df_insert.drop(columns=['artist', 'name'], inplace=True)
df_insert.rename(columns={'id': 'actor_id'}, inplace=True)
df_insert.to_sql('song_actor', engine, if_exists='append', index=False)
# Out:
# 356

# %% [markdown]
# ##### Platform

# %%
df_insert = pd.DataFrame(['spotify'], columns=['id'])
df_insert.to_sql('platform', engine, if_exists='append', index=False)
# Out:
# 1

# %% [markdown]
# ##### Score

# %%
list_insert = []
#pour chaque ligne
for song_id, timeSerie in df[['song_id', 'timeSeries']].astype(str).values:
    #timeseries to json
    #pour chaque ligne
    df_temp = pd.DataFrame(json.loads(timeSerie))
    if 'spotify-streams' in df_temp.columns and 'spotify-popularity' in df_temp.columns:
        for date, streams, popularity in df_temp[['date', 'spotify-streams', 'spotify-popularity']].values:
            list_insert.append([song_id, 'spotify', date, streams, popularity])
    elif not 'spotify-streams' in df_temp.columns and 'spotify-popularity' in df_temp.columns:
        for date, popularity in df_temp[['date', 'spotify-popularity']].values:
            list_insert.append([song_id, 'spotify', date, None, popularity])
    elif 'spotify-streams' in df_temp.columns and not 'spotify-popularity' in df_temp.columns:
        for date, streams in df_temp[['date', 'spotify-streams']].values:
            list_insert.append([song_id, 'spotify', date, streams, None])
    df_insert = pd.DataFrame(list_insert, columns=['song_id', 'platform_id', 'date', 'stream', 'popularity'])
    df_insert.to_sql('score', engine, if_exists='append', index=False)
    list_insert = []

# %% [markdown]
# ##### Statistic

# %%
#pour chaque ligne
list_insert = []
for song_id, summaries in df[['song_id', 'summaries']].astype(str).values:
    #summaries to json
    #pour stream et popularity
    df_temp = pd.DataFrame(json.loads(summaries))
    if 'spotify-streams' in df_temp.columns and 'spotify-popularity' in df_temp.columns:
        list_insert.append([song_id, 'spotify', 'streams', df_temp['spotify-streams']['value'], df_temp['spotify-streams']['lastDataPointDate'], df_temp['spotify-streams']['firstDataPointDate']])
        list_insert.append([song_id, 'spotify', 'popularity', df_temp['spotify-popularity']['value'], df_temp['spotify-popularity']['lastDataPointDate'], df_temp['spotify-popularity']['firstDataPointDate']])
    elif not 'spotify-streams' in df_temp.columns and 'spotify-popularity' in df_temp.columns:
        list_insert.append([song_id, 'spotify', 'popularity', df_temp['spotify-popularity']['value'], df_temp['spotify-popularity']['lastDataPointDate'], df_temp['spotify-popularity']['firstDataPointDate']])
    elif 'spotify-streams' in df_temp.columns and not 'spotify-popularity' in df_temp.columns:
        list_insert.append([song_id, 'spotify', 'streams', df_temp['spotify-streams']['value'], df_temp['spotify-streams']['lastDataPointDate'], df_temp['spotify-streams']['firstDataPointDate']])
df_insert = pd.DataFrame(list_insert, columns=['song_id', 'platform_id', 'metric', 'value', 'last_data_point_date', 'first_data_point_date'])
df_insert.to_sql('statistic', engine, if_exists='append', index=False)
# Out:
# 139

# %% [markdown]
# ##### Evolution

# %%
list_insert = []
df_temp = pd.read_sql("SELECT id, song_id, metric FROM statistic", engine)
df_temp['song_id'] = df_temp['song_id'].apply(lambda col: col.strip())
df_summaries = df[['song_id', 'summaries']].astype(str)
df_temp1 = df_temp.merge(df_summaries, how='left', left_on='song_id', right_on='song_id')
df_temp1.drop(columns=['song_id'], inplace=True)
for statistic_id, metric, summaries in df_temp1[['id', 'metric', 'summaries']].astype(str).values:
    df_temp2 = pd.DataFrame(json.loads(summaries))
    if metric == 'streams':
        if 'spotify-streams' in df_temp2.columns:
            df_temp3 = pd.DataFrame(df_temp2['spotify-streams']['periods'])
            for period in df_temp3.columns:
                if not 'comparedValue' in df_temp3[period]:
                    list_insert.append([statistic_id, period, df_temp3[period]['evolution'], df_temp3[period]['comparedDate'], 0, df_temp3[period]['percentEvolution']])
                else :
                    list_insert.append([statistic_id, period, df_temp3[period]['evolution'], df_temp3[period]['comparedDate'], df_temp3[period]['comparedValue'], df_temp3[period]['percentEvolution']])
    elif metric == 'popularity':
        if 'spotify-popularity' in df_temp2.columns:
            df_temp3 = pd.DataFrame(df_temp2['spotify-popularity']['periods'])
            for period in df_temp3.columns:
                if not 'comparedValue' in df_temp3[period]:
                    list_insert.append([statistic_id, period, df_temp3[period]['evolution'], df_temp3[period]['comparedDate'], 0, df_temp3[period]['percentEvolution']])
                else :
                    list_insert.append([statistic_id, period, df_temp3[period]['evolution'], df_temp3[period]['comparedDate'], df_temp3[period]['comparedValue'], df_temp3[period]['percentEvolution']])
    df_insert = pd.DataFrame(list_insert, columns=['statistic_id', 'period', 'evolution', 'compared_date', 'compared_value', 'percent_evolution'])
    df_insert.to_sql('evolution', engine, if_exists='append', index=False)
    list_insert = []

# %%
def delete_rows ():
    with engine.connect() as conn:
        result = conn.execute(
            text("DELETE FROM table")
        )
        print(f"{result.rowcount} lignes supprimées")
        conn.commit()

# %% [markdown]
# L'insertion de données est faite. Le dump complet est disponible dans le fichier dump.sql

# %% [markdown]
# ### Modélisation

# %% [markdown]
# #### Tendances générales

# %%
df_temp = pd.read_sql("select a.date, sum(a.stream) streams from public.score a where a.stream is not null group by date order by date ;", engine)
df_temp.plot(x='date', y='streams', kind='line', figsize=(15, 5), title='Streams dans le temps')
plt.show()

# %%
df_temp = pd.read_sql("select a.date, sum(a.stream) streams from public.score a where a.stream is not null and date<'2024-01-01' group by date order by date ;", engine)
df_temp.plot(x='date', y='streams', kind='line', figsize=(15, 5), title='Streams dans le temps')
plt.show()

# %%
df_temp = pd.read_sql("select a.release date, count(a.id) release from public.song a where release is not null group by release order by date ;", engine)
df_temp.plot(x='date', y='release', kind='line', figsize=(15, 5), title='Releases dans le temps')
plt.show()

# %%
#scatter plot streams et popularité
df_temp = pd.read_sql("select popularity, stream from public.score;", engine)
df_temp.plot(x='stream', y='popularity', kind='scatter', figsize=(15, 5), title='Nuage de points des streams et de la popularité')
plt.show()

# %% [markdown]
# #### Les tops

# %%
df_temp = pd.read_sql("select g.name, f.sum_stream streams from (select e.actor_id, sum(stream) sum_stream from (select c.actor_id, d.stream from (select a.song_id, b.stream from (select song_id ,max(date) date from public.score group by song_id) a, public.score b where b.date=a.date and a.song_id=b.song_id and stream is not null order by stream desc) d, public.song_actor c where c.song_id=d.song_id order by actor_id) e group by actor_id) f, public.artist g where g.id=f.actor_id order by streams desc limit 5;", engine)
df_temp.plot(x='name', y='streams', kind='bar', figsize=(15, 5), title='Top 5 des artistes les plus streamés')
plt.show()

# %%
df_temp = pd.read_sql("select e.name, avg(d.pop) popularité from (select c.actor_id, b.song_id, b.pop from (select a.song_id, avg(a.popularity) pop from public.score a where a.popularity is not null group by song_id) b, public.song_actor c where c.song_id=b.song_id) d, public.artist e where e.id=d.actor_id group by name order by popularité desc LIMIT 5 ;", engine)
df_temp.plot(x='name', y='popularité', kind='bar', figsize=(15, 5), title='Top 5 des artistes les plus populaires')
plt.show()

# %%
df_temp = pd.read_sql("SELECT a.name , count(actor_id) morceaux FROM public.artist a ,public.song_actor b  where a.id=b.actor_id group by name order by morceaux desc LIMIT 5 ;", engine)
df_temp.plot(x='name', y='morceaux', kind='bar', figsize=(15, 5), title='Top 5 des artistes avec le plus de morceaux')
plt.show()

# %%
df_temp = pd.read_sql("select a.name, b.somme collaborations from public.artist a, (select actor_id, count(actor_id) somme from (select a.actor_id ,b.song_id from public.song_actor a, (select song_id from (select song_id,count(song_id) somme from public.song_actor group by song_id order by somme) where somme>1) b where a.song_id=b.song_id) group by actor_id order by somme desc LIMIT 5) b where a.id=b.actor_id;", engine)
df_temp.plot(x='name', y='collaborations', kind='bar', figsize=(15, 5), title='Top 5 des artistes avec le plus de collaborations')
plt.show()

# %%
df_temp = pd.read_sql("select d.name morceaux, c.stream streams from (select a.song_id, b.stream from (select song_id ,max(date) date from public.score group by song_id) a, public.score b where b.date=a.date and a.song_id=b.song_id and stream is not null order by stream desc limit 5) c, public.song d where d.id=c.song_id;", engine)
df_temp.plot(x='morceaux', y='streams', kind='bar', figsize=(15, 5), title='Top 5 des morceaux les plus streamés')
plt.show()

# %%
df_temp = pd.read_sql("select c.name morceaux, b.pop popularité from (select a.song_id, avg(a.popularity) pop from public.score a where a.popularity is not null group by song_id order by pop desc limit 5) b, public.song c where c.id=b.song_id;", engine)
df_temp.plot(x='morceaux', y='popularité', kind='bar', figsize=(15, 5), title='Top 5 des morceaux les plus populaires')
plt.show()

# %% [markdown]
# ### Enrichissement

# %% [markdown]
# #### Statistiques générales

# %%
df_temp = pd.read_sql("select b.stream streams from (select song_id ,max(date) date from public.score group by song_id) a, public.score b where b.date=a.date and a.song_id=b.song_id and stream is not null order by stream desc;", engine)
print(df_temp.describe().map(lambda x: f"{x:,.0f}".replace(",", " ") if isinstance(x, (int, float)) else x));
# Out:
#              streams
# count          8 448
# mean      10 381 832
# std       66 808 879
# min            1 001
# 25%            7 683
# 50%           56 469
# 75%          624 005
# max    2 145 891 205

# %%
valeur = df_temp.median().iloc[0]
valeur_formatee = f"{int(valeur):,}".replace(",", " ")
print('Médiane des streams : ',valeur_formatee)
# Out:
# Médiane des streams :  56 469

# %%
df_temp.plot(kind='box', title='Boîte à moustaches des streams')
plt.show()

# %%
df_temp = pd.read_sql("select avg(c.b) from (select a.actor_id, count(a.song_id) b from public.song_actor a group by actor_id order by b desc) c;", engine)
valeur = df_temp['avg'].iloc[0]
valeur_formatee = f"{round(valeur, 2):,}".replace(",", " ")
print('Moyenne de morceaux par artiste : ',valeur_formatee)
# Out:
# Moyenne de morceaux par artiste :  5.36

# %%
df_temp = pd.read_sql("select avg(h.sum_stream) from (select g.name, f.sum_stream from (select e.actor_id, sum(stream) sum_stream from (select c.actor_id, d.stream from (select a.song_id, b.stream from (select song_id ,max(date) date from public.score group by song_id) a, public.score b where b.date=a.date and a.song_id=b.song_id and stream is not null order by stream desc) d, public.song_actor c where c.song_id=d.song_id order by actor_id) e group by actor_id ) f, public.artist g where g.id=f.actor_id) h;", engine)
valeur = df_temp['avg'].iloc[0]
valeur_formatee = f"{int(valeur):,}".replace(",", " ")
print('Moyenne de streams par artiste : ',valeur_formatee)
# Out:
# Moyenne de streams par artiste :  44 584 134

# %%
df_temp = pd.read_sql("select avg(b.count_artist) from (select count(a.song_id) count_artist from public.song_actor a group by song_id) b;", engine)
valeur = df_temp['avg'].iloc[0]
valeur_formatee = f"{round(valeur, 2):,}".replace(",", " ")
print("Moyenne d'artiste par morceau : ",valeur_formatee)
# Out:
# Moyenne d'artiste par morceau :  1.66

# %% [markdown]
# #### Corrélations

# %%
df_temp = pd.read_sql("SELECT corr(a.stream, a.popularity) AS correlation FROM public.score a WHERE stream IS NOT NULL AND popularity IS NOT NULL;", engine)
valeur = df_temp['correlation'].iloc[0]
valeur_formatee = f"{round(valeur, 5):,}".replace(",", " ")
print('Corrélation entre les streams et la popularité : ',valeur_formatee)
# Out:
# Corrélation entre les streams et la popularité :  0.3867

# %%
df_temp = pd.read_sql("select corr(f.sum_stream, g.nbr_song) AS correlation from (select e.actor_id, sum(stream) sum_stream from (select c.actor_id, d.stream from (select a.song_id, b.stream from (select song_id ,max(date) date from public.score group by song_id) a, public.score b where b.date=a.date and a.song_id=b.song_id and stream is not null order by stream desc) d, public.song_actor c where c.song_id=d.song_id order by actor_id) e group by actor_id ) f, (SELECT b.actor_id , count(actor_id) nbr_song FROM public.song_actor b group by actor_id ) g where f.actor_id=g.actor_id;", engine)
valeur = df_temp['correlation'].iloc[0]
valeur_formatee = f"{round(valeur, 5):,}".replace(",", " ")
print('Corrélation entre les streams et le nombre de morceaux : ',valeur_formatee)
# Out:
# Corrélation entre les streams et le nombre de morceaux :  0.27657

# %%
df_temp = pd.read_sql("select corr(d.stream, e.nbr_actor) correlation from (select a.song_id, b.stream from (select song_id ,max(date) date from public.score group by song_id) a, public.score b where b.date=a.date and a.song_id=b.song_id and stream is not null order by stream desc ) d, (select c.song_id, count(c.song_id) nbr_actor from public.song_actor c group by song_id) e where d.song_id=e.song_id;", engine)
valeur = df_temp['correlation'].iloc[0]
valeur_formatee = f"{round(valeur, 5):,}".replace(",", " ")
print("Corrélation entre les streams et le nombre d'artistes sur le morceaux : ",valeur_formatee)
# Out:
# Corrélation entre les streams et le nombre d'artistes sur le morceaux :  -0.01114

# %% [markdown]
# #### Etude particulière

# %% [markdown]
# ##### Pour un morceau (en exemple au hasard)

# %%
# A executer pour l'exemple
song_id = '003a2665-9881-49f1-9ae1-6b6ebe46f35e'
actor_id = 34082

# %%
query = text("select stream, date from public.score where song_id= :song_id;")
df_temp = pd.read_sql(query, engine, params={"song_id": song_id})
df_temp.plot(x='date', y='stream', kind='line', figsize=(15, 5), title="Streams dans le temps d'un morceau")
plt.show()

# %%
query = text("select popularity, date from public.score where song_id= :song_id;")
df_temp = pd.read_sql(query, engine, params={"song_id": song_id})
df_temp.plot(x='date', y='popularity', kind='line', figsize=(15, 5), title="Popularité dans le temps d'un morceau")
plt.show()

# %% [markdown]
# ##### Pour un artiste (en exemple au hasard)

# %%
query = text("select d.name, c.date, c.stream from (select a.song_id, b.date, b.stream from (select song_id from public.song_actor where actor_id=:actor_id) a, public.score b where b.song_id=a.song_id) c, public.song d where c.song_id=d.id;")
df_temp = pd.read_sql(query, engine, params={"actor_id": actor_id})
df_temp['date'] = pd.to_datetime(df_temp['date'], errors='coerce')
plt.figure(figsize=(15, 5))
sns.lineplot(data=df_temp, x='date', y='stream', hue='name')
plt.title("Évolution des streams dans le temps par morceau")
plt.xlabel("Date")
plt.ylabel("Streams")
plt.xticks(rotation=45)  # Pour une meilleure lisibilité des dates
plt.legend(title='Morceau', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
